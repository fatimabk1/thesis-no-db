# %%
# %run store.py
# Out:
# -------------------------------------------------------------------------------------------------- DAY 0: 9/15/2019
# GRP_0:	PENDING=0	BACK=266644	SHELF=17796	SOLD=360	TOSS=0	ORDER_THRESHOLD=267000
# -------------------------------------------------------------------------------------------------- DAY 1: 9/16/2019
# GRP_0:	PENDING=0	BACK=266284	SHELF=17788	SOLD=368	TOSS=0	ORDER_THRESHOLD=267000
# -------------------------------------------------------------------------------------------------- DAY 2: 9/17/2019
# GRP_0:	PENDING=0	BACK=265901	SHELF=17791	SOLD=380	TOSS=0	ORDER_THRESHOLD=267000
# -------------------------------------------------------------------------------------------------- DAY 3: 9/18/2019
# GRP_0:	PENDING=0	BACK=265497	SHELF=17792	SOLD=403	TOSS=0	ORDER_THRESHOLD=267000
# -------------------------------------------------------------------------------------------------- DAY 4: 9/19/2019
# GRP_0:	PENDING=0	BACK=265068	SHELF=17791	SOLD=430	TOSS=0	ORDER_THRESHOLD=267000
# ...

# %% [markdown]
# Data Visualization for One Day:
